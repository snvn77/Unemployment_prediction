# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from math import sqrt

from scipy import stats

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.stats.stattools import durbin_watson

from keras.models import Sequential
from keras.layers import LSTM, Dense, Bidirectional, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# # Loading the data

# %%
data = pd.read_excel("Data.xlsx", sheet_name="Final")

# %% [markdown]
# # Adding date column and making it the index

# %%
# Convert 'Year' and 'Month' into a proper Date column
data["Date"] = pd.to_datetime(data["Year"].astype(str) + " " + data["Month"], format="%Y %b")

# Drop the redundant 'Year' and 'Month' columns
data = data.drop(columns=["Year", "Month"])

# %%
# Set Date as index
data = data.set_index("Date")

# Explicitly set monthly frequency to avoid warnings
data = data.asfreq("MS")

# %%
data
# Out:
#             Unemployment Rate (Percent)  \
# Date
# 2000-12-01                          3.9
# 2001-01-01                          4.2
# 2001-02-01                          4.2
# 2001-03-01                          4.3
# 2001-04-01                          4.4
# ...                                 ...
# 2024-09-01                          4.1
# 2024-10-01                          4.1
# 2024-11-01                          4.2
# 2024-12-01                          4.1
# 2025-01-01                          4.0
#
#             Civilian Labor Force (Thousands of people)  \
# Date
# 2000-12-01                                      143248
# 2001-01-01                                      143800
# 2001-02-01                                      143701
# 2001-03-01                                      143924
# 2001-04-01                                      143569
# ...                                                ...
# 2024-09-01                                      168703
# 2024-10-01                                      168428
# 2024-11-01                                      168304
# 2024-12-01                                      168547
# 2025-01-01                                      170744
#
#             Hires level (Thousands of people)  \
# Date
# 2000-12-01                               5426
# 2001-01-01                               5722
# 2001-02-01                               5303
# 2001-03-01                               5528
# 2001-04-01                               5204
# ...                                       ...
# 2024-09-01                               5519
# 2024-10-01                               5350
# 2024-11-01                               5307
# 2024-12-01                               5374
# 2025-01-01                               5393
#
#             Separations level (Thousands of people)  \
# Date
# 2000-12-01                                     5240
# 2001-01-01                                     5842
# 2001-02-01                                     5231
# 2001-03-01                                     5566
# 2001-04-01                                     5414
# ...                                             ...
# 2024-09-01                                     5197
# 2024-10-01                                     5285
# 2024-11-01                                     5087
# 2024-12-01                                     5082
# 2025-01-01                                     5252
#
#             Disposable Personal Income SAAR (Billions of Dollars)  \
# Date
# 2000-12-01                                             7579.4
# 2001-01-01                                             7651.7
# 2001-02-01                                             7672.4
# 2001-03-01                                             7696.3
# 2001-04-01                                             7693.8
# ...                                                       ...
# 2024-09-01                                            21712.5
# 2024-10-01                                            21851.5
# 2024-11-01                                            21917.6
# 2024-12-01                                            22015.6
# 2025-01-01                                            22209.8
#
#             Personal Consumption Expenditures SAAR (Billions of Dollars)  \
# Date
# 2000-12-01                                             6952.2
# 2001-01-01                                             6987.4
# 2001-02-01                                             7001.8
# 2001-03-01                                             6996.7
# 2001-04-01                                             7004.2
# ...                                                       ...
# 2024-09-01                                            20044.1
# 2024-10-01                                            20133.0
# 2024-11-01                                            20242.7
# 2024-12-01                                            20412.5
# 2025-01-01                                            20381.8
#
#             Personal Savings SAAR (Billions of Dollars)  Manufacturing PMI  \
# Date
# 2000-12-01                                        307.2               48.5
# 2001-01-01                                        344.7               43.9
# 2001-02-01                                        350.7               42.3
# 2001-03-01                                        380.1               42.1
# 2001-04-01                                        369.3               43.1
# ...                                                 ...                ...
# 2024-09-01                                        830.7               47.2
# 2024-10-01                                        881.0               47.2
# 2024-11-01                                        838.1               46.5
# 2024-12-01                                        766.7               48.4
# 2025-01-01                                       1013.7               49.2
#
#             Manufacturing Employment Index  Services Employment Index  \
# Date
# 2000-12-01                            47.1                       54.6
# 2001-01-01                            42.7                       52.4
# 2001-02-01                            42.3                       51.7
# 2001-03-01                            37.8                       50.7
# 2001-04-01                            39.9                       49.6
# ...                                    ...                        ...
# 2024-09-01                            46.0                       50.2
# 2024-10-01                            43.9                       48.1
# 2024-11-01                            44.4                       53.0
# 2024-12-01                            48.1                       51.5
# 2025-01-01                            45.4                       51.3
#
#             Advance Monthly Sales for retail & food services (Millions of Dollars)  \
# Date
# 2000-12-01                                             275791
# 2001-01-01                                             278834
# 2001-02-01                                             278773
# 2001-03-01                                             276450
# 2001-04-01                                             280808
# ...                                                       ...
# 2024-09-01                                             716388
# 2024-10-01                                             720393
# 2024-11-01                                             725079
# 2024-12-01                                             730300
# 2025-01-01                                             723853
#
#                 CPI
# Date
# 2000-12-01  174.000
# 2001-01-01  175.100
# 2001-02-01  175.800
# 2001-03-01  176.200
# 2001-04-01  176.900
# ...             ...
# 2024-09-01  315.301
# 2024-10-01  315.664
# 2024-11-01  315.493
# 2024-12-01  315.605
# 2025-01-01  317.671
#
# [290 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 290 entries, 2000-12-01 to 2025-01-01
# Freq: MS
# Data columns (total 12 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Unemployment Rate (Percent)                                             290 non-null    float64
#  1   Civilian Labor Force (Thousands of people)                              290 non-null    int64
#  2   Hires level (Thousands of people)                                       290 non-null    int64
#  3   Separations level (Thousands of people)                                 290 non-null    int64
#  4   Disposable Personal Income SAAR (Billions of Dollars)                   290 non-null    float64
#  5   Personal Consumption Expenditures SAAR (Billions of Dollars)            290 non-null    float64
#  6   Personal Savings SAAR (Billions of Dollars)                             290 non-null    float64
#  7   Manufacturing PMI                                                       290 non-null    float64
#  8   Manufacturing Employment Index                                          290 non-null    float64
#  9   Services Employment Index                                               290 non-null    float64
#  10  Advance Monthly Sales for retail & food services (Millions of Dollars)  290 non-null    int64
#  11  CPI                                                                     290 non-null    float64
# dtypes: float64(8), int64(4)
# memory usage: 29.5 KB

# %%
data.describe()
# Out:
#        Unemployment Rate (Percent)  \
# count                   290.000000
# mean                      5.755172
# std                       1.967467
# min                       3.400000
# 25%                       4.300000
# 50%                       5.200000
# 75%                       6.675000
# max                      14.800000
#
#        Civilian Labor Force (Thousands of people)  \
# count                                  290.000000
# mean                                155940.189655
# std                                   6711.629327
# min                                 143248.000000
# 25%                                 152493.750000
# 50%                                 155223.500000
# 75%                                 160896.250000
# max                                 170744.000000
#
#        Hires level (Thousands of people)  \
# count                         290.000000
# mean                         5188.610345
# std                           696.919914
# min                          3639.000000
# 25%                          4692.250000
# 50%                          5216.000000
# 75%                          5576.000000
# max                          8133.000000
#
#        Separations level (Thousands of people)  \
# count                               290.000000
# mean                               5094.003448
# std                                 934.209984
# min                                3884.000000
# 25%                                4718.000000
# 50%                                5099.500000
# 75%                                5389.500000
# max                               16275.000000
#
#        Disposable Personal Income SAAR (Billions of Dollars)  \
# count                                         290.000000
# mean                                        13204.596207
# std                                          3967.444327
# min                                          7579.400000
# 25%                                         10176.250000
# 50%                                         12374.400000
# 75%                                         15941.575000
# max                                         22209.800000
#
#        Personal Consumption Expenditures SAAR (Billions of Dollars)  \
# count                                         290.000000
# mean                                        11960.440690
# std                                          3523.607838
# min                                          6952.200000
# 25%                                          9500.900000
# 50%                                         11216.800000
# 75%                                         14035.050000
# max                                         20412.500000
#
#        Personal Savings SAAR (Billions of Dollars)  Manufacturing PMI  \
# count                                   290.000000         290.000000
# mean                                    793.724138          52.528966
# std                                     663.150404           5.306442
# min                                     128.900000          33.300000
# 25%                                     431.250000          49.200000
# 50%                                     706.250000          52.600000
# 75%                                     903.825000          56.500000
# max                                    5981.600000          64.700000
#
#        Manufacturing Employment Index  Services Employment Index  \
# count                      290.000000                 290.000000
# mean                        50.468621                  51.486172
# std                          6.367865                   5.103864
# min                         26.400000                  30.000000
# 25%                         47.300000                  49.100000
# 50%                         51.300000                  52.500000
# 75%                         54.675000                  54.975000
# max                         61.900000                  62.400000
#
#        Advance Monthly Sales for retail & food services (Millions of Dollars)  \
# count                                         290.000000
# mean                                       440020.572414
# std                                        125447.981684
# min                                        275791.000000
# 25%                                        346599.000000
# 50%                                        408488.500000
# 75%                                        500929.500000
# max                                        730300.000000
#
#               CPI
# count  290.000000
# mean   232.420852
# std     37.419185
# min    174.000000
# 25%    203.499250
# 50%    231.362000
# 75%    252.691750
# max    317.671000

# %% [markdown]
# # Analysing the Target Variable

# %%
plt.figure(figsize=(15, 7))
plt.plot(data.index, data['Unemployment Rate (Percent)'], label='Unemployment Rate (Percent)')
plt.title('Unemployment Rate Over Time')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# # ACF and PACF plots

# %%
# Plot the ACF
plt.figure(figsize=(12, 6))
plot_acf(data['Unemployment Rate (Percent)'], alpha=0.05, lags=40)
plt.title('Autocorrelation Function')

# Plot the PACF
plt.figure(figsize=(12, 6))
plot_pacf(data['Unemployment Rate (Percent)'], alpha=0.05, lags=40)
plt.title('Partial Autocorrelation Function')

plt.show()

# %%
# Perform the Dickey-Fuller test on the 'Unemployment Rate' time series
result = adfuller(data['Unemployment Rate (Percent)'])

# Create a more readable summary of the test
df_output = pd.Series(result[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
for key, value in result[4].items():
    df_output['Critical Value (%s)' % key] = value

print(df_output)
# Out:
# Test Statistic                  -2.928951
# p-value                          0.042083
# #Lags Used                       0.000000
# Number of Observations Used    289.000000
# Critical Value (1%)             -3.453182
# Critical Value (5%)             -2.871593
# Critical Value (10%)            -2.572127
# dtype: float64

# %% [markdown]
# The p-value and test statistic from the Dickey-Fuller test suggest that the series is marginally stationary at a 5% level. However, the time plot and the ACF indicate non-stationarity due to the presence of trends and possibly changing variance. Given the non-stationary visual indicators and the marginal p-value, it's cautious to assume non-stationarity. Therefore, differencing is done.

# %%
data1 = data.copy()

# %%
data1['Differenced_Target'] = data1['Unemployment Rate (Percent)'].diff()

# The first element of the differenced series will be NaN because there is nothing to subtract from the first element
# You can drop the NaN value or fill it if needed
data1 = data1.dropna()

# Plotting the differenced data
data1['Differenced_Target'].plot(figsize=(15, 7), title='Differenced Unemployment Rate Over Time')
plt.xlabel('Time')
plt.ylabel('Differenced Value')
plt.show()

# %%
# Perform the Dickey-Fuller test on the 'Unemployment Rate' time series
result = adfuller(data1['Differenced_Target'])

# Create a more readable summary of the test
df_output = pd.Series(result[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
for key, value in result[4].items():
    df_output['Critical Value (%s)' % key] = value

print(df_output)
# Out:
# Test Statistic                -1.004759e+01
# p-value                        1.440671e-17
# #Lags Used                     3.000000e+00
# Number of Observations Used    2.850000e+02
# Critical Value (1%)           -3.453505e+00
# Critical Value (5%)           -2.871735e+00
# Critical Value (10%)          -2.572202e+00
# dtype: float64

# %% [markdown]
# # Modelling without any exogenous variables

# %% [markdown]
# ACF Plot: Shows a gradual decline, which is typical for an AR process. However, after differencing, if the ACF plot drops off sharply after a lag, this would indicate the number of MA terms.
#
# PACF Plot: Shows a significant spike at lag 1 and cuts off, which suggests an AR(1) process. The spike at lag 1 in the PACF plot typically indicates one AR term.
#
# Based on this information, we can tentatively specify an ARIMA model. Since the data has been differenced once to achieve stationarity, the integrated component (I) is 1. The AR component (p) can be taken as 1 due to the spike in the PACF at lag 1. The MA component (q) can initially be taken as 0 since there is no significant spike in the ACF plot after the first lag that cuts off in the PACF plot.
#
# This leads to an initial ARIMA model of (1,1,0).

# %% [markdown]
# # Model 1 - ARIMA(1,1,0)

# %%
# 1. Split the Data
train_size = int(len(data1) * 0.8)  # 80% for training, 20% for testing
train, test = data1[0:train_size], data1[train_size:]

# 2. Fit the ARIMA Model
# Starting with parameters p=1, d=0, q=1
model = ARIMA(train['Differenced_Target'], order=(1,1,0))
model_fit = model.fit()

# 3. Model Diagnostics
model_fit.plot_diagnostics(figsize=(10, 8))
plt.show()

# 4. Forecasting
forecast = model_fit.get_forecast(steps=len(test))
forecast_mean = forecast.predicted_mean

# Assume 'original_data' contains your entire non-differenced dataset
last_actual_value = data['Unemployment Rate (Percent)'].iloc[-1]  # last value of the original dataset

# Forecast the next three values beyond the test set (as previously described)
total_steps = len(test) + 12
extended_forecast = model_fit.get_forecast(steps=total_steps)
extended_forecast_mean = extended_forecast.predicted_mean

# Dedifference forecast values
# Start with the last actual value from the original data
next_values = [last_actual_value + extended_forecast_mean.iloc[len(test)]]

# Now cumulatively add the forecasted differences to get absolute values
for i in range(1, 12):
    next_value = next_values[i-1] + extended_forecast_mean.iloc[len(test) + i]
    next_values.append(next_value)

print("Dedifferenced forecasted values:")
print(next_values)
# Out:
# Dedifferenced forecasted values:
# [4.534701346941515, 5.069402693883034, 5.60410404082455, 6.138805387766069, 6.673506734707586, 7.208208081649103, 7.742909428590621, 8.277610775532139, 8.812312122473656, 9.347013469415174, 9.881714816356691, 10.416416163298209]

# %%
# Model Evaluation on the differenced scale
mse = mean_squared_error(test['Differenced_Target'], forecast_mean)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test['Differenced_Target'], forecast_mean)
print(f'Mean Absolute Error (MAE): {mae}')
print(f'The Mean Squared Error of the forecasts is {mse}')
print(f'The Root Mean Squared Error of the forecasts is {rmse}')

# Extract AIC and BIC values
aic = model_fit.aic
bic = model_fit.bic
print(f'AIC: {aic}')
print(f'BIC: {bic}')

# Plotting Actual vs. Predicted values
plt.figure(figsize=(12, 6))
plt.plot(test.index, test['Differenced_Target'], label='Actual Differenced Values', color='blue')
plt.plot(test.index, forecast_mean, label='Predicted Differenced Values', color='orange')
plt.title('Actual vs Predicted Differenced Values')
plt.xlabel('Date')
plt.ylabel('Differenced Unemployment Rate (Percent)')
plt.legend()
plt.show()
# Out:
# Mean Absolute Error (MAE): 0.8867297126732743
# The Mean Squared Error of the forecasts is 2.4726444968829027
# The Root Mean Squared Error of the forecasts is 1.5724644660159741
# AIC: -141.16130572566604
# BIC: -134.28514710781965

# %% [markdown]
# # Model 2 - ARIMA(1,1,1)

# %%
# 2. Fit the second ARIMA Model
# Starting with parameters p=1, d=1, q=1
model2 = ARIMA(train['Differenced_Target'], order=(1,1,1))
model2_fit = model2.fit()

# 3. Model Diagnostics
model2_fit.plot_diagnostics(figsize=(10, 8))
plt.show()

# 4. Forecasting
forecast2 = model2_fit.get_forecast(steps=len(test))
forecast_mean2 = forecast2.predicted_mean

# Assume 'original_data' contains your entire non-differenced dataset
last_actual_value = data['Unemployment Rate (Percent)'].iloc[-1]  # last value of the original dataset

# Forecast the next three values beyond the test set (as previously described)
total_steps = len(test) + 12
extended_forecast = model2_fit.get_forecast(steps=total_steps)
extended_forecast_mean = extended_forecast.predicted_mean

# Dedifference forecast values
# Start with the last actual value from the original data
next_values = [last_actual_value + extended_forecast_mean.iloc[len(test)]]

# Now cumulatively add the forecasted differences to get absolute values
for i in range(1, 12):
    next_value = next_values[i-1] + extended_forecast_mean.iloc[len(test) + i]
    next_values.append(next_value)

print("Dedifferenced forecasted values:")
print(next_values)

# 5. Model Evaluation
mse2 = mean_squared_error(test['Differenced_Target'], forecast_mean2)
rmse2 = np.sqrt(mse2)
mae = mean_absolute_error(test['Differenced_Target'], forecast_mean2)
print(f'Mean Absolute Error (MAE): {mae}')
print(f'The Mean Squared Error of the forecasts is {mse2}')
print(f'The Root Mean Squared Error of the forecasts is {rmse2}')

# Extract AIC and BIC values
aic2 = model2_fit.aic
bic2 = model2_fit.bic
print(f'AIC: {aic2}')
print(f'BIC: {bic2}')

# Plotting Actual vs. Predicted values
plt.figure(figsize=(12, 6))
plt.plot(test.index, test['Differenced_Target'], label='Actual Differenced Values', color='blue')
plt.plot(test.index, forecast_mean2, label='Predicted Differenced Values', color='orange')
plt.title('Actual vs Predicted Differenced Values')
plt.xlabel('Date')
plt.ylabel('Differenced Unemployment Rate (Percent)')
plt.legend()
plt.show()
# Out:
# Dedifferenced forecasted values:
# [4.150615017482829, 4.301230034965657, 4.451845052448486, 4.602460069931315, 4.753075087414143, 4.903690104896972, 5.054305122379801, 5.2049201398626295, 5.355535157345458, 5.506150174828287, 5.6567651923111155, 5.807380209793944]
# Mean Absolute Error (MAE): 0.5187029885693282
# The Mean Squared Error of the forecasts is 2.1776063817127835
# The Root Mean Squared Error of the forecasts is 1.4756715019653879
# AIC: -191.41656770660109
# BIC: -181.1023297798315

# %% [markdown]
# # Exploratory Data Analysis of Exogenous variables

# %%
# Define the target variable
target_variable = 'Unemployment Rate (Percent)'

# Get the list of all variables except the target variable
exogenous_variables = data.columns[data.columns != target_variable]

# Create scatter plots for each exogenous variable against the target variable
for variable in exogenous_variables:
    plt.figure(figsize=(8, 6))
    plt.scatter(data[variable], data[target_variable], alpha=0.5)
    plt.title(f'Scatter Plot: {variable} vs. {target_variable}')
    plt.xlabel(variable)
    plt.ylabel(target_variable)
    plt.grid(True)
    plt.show()

# %%
for variable in exogenous_variables:
    plt.figure(figsize=(15, 7))
    plt.plot(data.index, data[variable], label=variable)
    plt.title(variable)
    plt.xlabel('Time')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# %%
# Calculate the correlation matrix
corr_matrix = data.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
data_filtered=data.copy()

# %%
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 290 entries, 2000-12-01 to 2025-01-01
# Freq: MS
# Data columns (total 12 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Unemployment Rate (Percent)                                             290 non-null    float64
#  1   Civilian Labor Force (Thousands of people)                              290 non-null    int64
#  2   Hires level (Thousands of people)                                       290 non-null    int64
#  3   Separations level (Thousands of people)                                 290 non-null    int64
#  4   Disposable Personal Income SAAR (Billions of Dollars)                   290 non-null    float64
#  5   Personal Consumption Expenditures SAAR (Billions of Dollars)            290 non-null    float64
#  6   Personal Savings SAAR (Billions of Dollars)                             290 non-null    float64
#  7   Manufacturing PMI                                                       290 non-null    float64
#  8   Manufacturing Employment Index                                          290 non-null    float64
#  9   Services Employment Index                                               290 non-null    float64
#  10  Advance Monthly Sales for retail & food services (Millions of Dollars)  290 non-null    int64
#  11  CPI                                                                     290 non-null    float64
# dtypes: float64(8), int64(4)
# memory usage: 29.5 KB

# %% [markdown]
# # Drop the mutually correlated columns (to avoid multi collinearity) and columns with no relationship to Unemployment levels

# %%
# Drop the disposable income column as it is causing multicolinearity
data_filtered.drop(['Disposable Personal Income SAAR (Billions of Dollars)','Personal Consumption Expenditures SAAR (Billions of Dollars)','Manufacturing PMI','Manufacturing Employment Index','Advance Monthly Sales for retail & food services (Millions of Dollars)'], axis=1, inplace=True)

# %%
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 290 entries, 2000-12-01 to 2025-01-01
# Freq: MS
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unemployment Rate (Percent)                  290 non-null    float64
#  1   Civilian Labor Force (Thousands of people)   290 non-null    int64
#  2   Hires level (Thousands of people)            290 non-null    int64
#  3   Separations level (Thousands of people)      290 non-null    int64
#  4   Personal Savings SAAR (Billions of Dollars)  290 non-null    float64
#  5   Services Employment Index                    290 non-null    float64
#  6   CPI                                          290 non-null    float64
# dtypes: float64(4), int64(3)
# memory usage: 18.1 KB

# %%
# Define the target variable
target_variable = 'Unemployment Rate (Percent)'

# Get the list of all variables except the target variable
exogenous_variables = data_filtered.columns[data_filtered.columns != target_variable]

# %% [markdown]
# # Checking for Stationarity in the exogenous variables

# %%
# Function to run ADF test
def adf_test(series, title=''):
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(), autolag='AIC')  # Drop na to avoid invalid computation
    labels = ['ADF test statistic', 'p-value', '# lags', '# observations']
    out = pd.Series(result[0:4], index=labels)

    for key, val in result[4].items():
        out[f'critical value ({key})'] = val
    print(out.to_string())  # .to_string() so it doesn't print in the scientific notation

    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")
    print("\n")

# Apply the ADF test to each of the exogenous variables
for var in exogenous_variables:
    adf_test(data_filtered[var], title=var)
# Out:
# Augmented Dickey-Fuller Test: Civilian Labor Force (Thousands of people)
# ADF test statistic       -0.070801
# p-value                   0.952270
# # lags                    2.000000
# # observations          287.000000
# critical value (1%)      -3.453342
# critical value (5%)      -2.871664
# critical value (10%)     -2.572164
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: Hires level (Thousands of people)
# ADF test statistic       -1.337036
# p-value                   0.612063
# # lags                    4.000000
# # observations          285.000000
# critical value (1%)      -3.453505
# critical value (5%)      -2.871735
# critical value (10%)     -2.572202
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: Separations level (Thousands of people)
# ADF test statistic       -2.776185
# p-value                   0.061757
# # lags                    7.000000
# # observations          282.000000
# critical value (1%)      -3.453754
# critical value (5%)      -2.871844
# critical value (10%)     -2.572261
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: Personal Savings SAAR (Billions of Dollars)
# ADF test statistic       -2.719244
# p-value                   0.070767
# # lags                   13.000000
# # observations          276.000000
# critical value (1%)      -3.454267
# critical value (5%)      -2.872070
# critical value (10%)     -2.572381
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: Services Employment Index
# ADF test statistic       -4.124519
# p-value                   0.000882
# # lags                    1.000000
# # observations          288.000000
# critical value (1%)      -3.453262
# critical value (5%)      -2.871628
# critical value (10%)     -2.572146
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: CPI
# ADF test statistic        0.917004
# p-value                   0.993308
# # lags                   12.000000
# # observations          277.000000
# critical value (1%)      -3.454180
# critical value (5%)      -2.872031
# critical value (10%)     -2.572360
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %% [markdown]
# # Differencing to make the exogenous variables stationary

# %%
# Differencing the non-stationary variables
data_diff = data_filtered.copy()
data_diff['Hires level (Thousands of people)'] = data_filtered['Hires level (Thousands of people)'].diff()
data_diff['Personal Savings SAAR (Billions of Dollars)'] = data_filtered['Personal Savings SAAR (Billions of Dollars)'].diff()
data_diff['Civilian Labor Force (Thousands of people)'] = data_filtered['Civilian Labor Force (Thousands of people)'].diff()
data_diff['CPI'] = data_filtered['CPI'].diff()
data_diff['Separations level (Thousands of people)'] = data_filtered['Separations level (Thousands of people)'].diff()
data_diff['Unemployment Rate (Percent)'] = data_filtered['Unemployment Rate (Percent)'].diff()

# Drop the first row since differencing will create NaN values
data_diff = data_diff.dropna()

# %%
data_diff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 289 entries, 2001-01-01 to 2025-01-01
# Freq: MS
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unemployment Rate (Percent)                  289 non-null    float64
#  1   Civilian Labor Force (Thousands of people)   289 non-null    float64
#  2   Hires level (Thousands of people)            289 non-null    float64
#  3   Separations level (Thousands of people)      289 non-null    float64
#  4   Personal Savings SAAR (Billions of Dollars)  289 non-null    float64
#  5   Services Employment Index                    289 non-null    float64
#  6   CPI                                          289 non-null    float64
# dtypes: float64(7)
# memory usage: 18.1 KB

# %%
# Apply the ADF test to each of the exogenous variables
for var in exogenous_variables:
    adf_test(data_diff[var], title=var)
# Out:
# Augmented Dickey-Fuller Test: Civilian Labor Force (Thousands of people)
# ADF test statistic     -1.362997e+01
# p-value                 1.730844e-25
# # lags                  1.000000e+00
# # observations          2.870000e+02
# critical value (1%)    -3.453342e+00
# critical value (5%)    -2.871664e+00
# critical value (10%)   -2.572164e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: Hires level (Thousands of people)
# ADF test statistic     -1.360842e+01
# p-value                 1.893601e-25
# # lags                  3.000000e+00
# # observations          2.850000e+02
# critical value (1%)    -3.453505e+00
# critical value (5%)    -2.871735e+00
# critical value (10%)   -2.572202e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: Separations level (Thousands of people)
# ADF test statistic     -1.065026e+01
# p-value                 4.681051e-19
# # lags                  6.000000e+00
# # observations          2.820000e+02
# critical value (1%)    -3.453754e+00
# critical value (5%)    -2.871844e+00
# critical value (10%)   -2.572261e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: Personal Savings SAAR (Billions of Dollars)
# ADF test statistic       -4.873748
# p-value                   0.000039
# # lags                   12.000000
# # observations          276.000000
# critical value (1%)      -3.454267
# critical value (5%)      -2.872070
# critical value (10%)     -2.572381
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: Services Employment Index
# ADF test statistic       -4.108356
# p-value                   0.000938
# # lags                    1.000000
# # observations          287.000000
# critical value (1%)      -3.453342
# critical value (5%)      -2.871664
# critical value (10%)     -2.572164
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: CPI
# ADF test statistic       -2.791431
# p-value                   0.059508
# # lags                   11.000000
# # observations          277.000000
# critical value (1%)      -3.454180
# critical value (5%)      -2.872031
# critical value (10%)     -2.572360
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
for variable in exogenous_variables:
    plt.figure(figsize=(15, 7))
    plt.plot(data_diff.index, data_diff[variable], label=variable)
    plt.title(variable)
    plt.xlabel('Time')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# %% [markdown]
# # Modelling with exogenous varibales

# %% [markdown]
# # SARIMAX(1,1,1) with 6 exogenous variables

# %%
# Prepare the exogenous variables (features) and the endogenous variable (target)
exog = data_diff[exogenous_variables]
endog = data_diff[target_variable]

# Split the data into train and test sets
train_size = int(len(data_diff) * 0.8)
train_endog = endog[:train_size]
train_exog = exog[:train_size]
test_endog = endog[train_size:]
test_exog = exog[train_size:]

# Fit the ARIMAX model
model = SARIMAX(train_endog, exog=train_exog, order=(1,1,1))
model_fit = model.fit()

# Summary of the model
print(model_fit.summary())

# Predictions
predictions = model_fit.get_forecast(steps=len(test_endog), exog=test_exog)
predicted_means = predictions.predicted_mean
predicted_intervals = predictions.conf_int()




# Calculate the error metrics
mae = mean_absolute_error(test_endog, predicted_means)
mse = mean_squared_error(test_endog, predicted_means)
rmse = mse**0.5

# Extract AIC and BIC values
aic = model_fit.aic
bic = model_fit.bic
print(f'AIC: {aic}')
print(f'BIC: {bic}')


# Output the error metrics
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
# Out:
#                                     SARIMAX Results
# =======================================================================================
# Dep. Variable:     Unemployment Rate (Percent)   No. Observations:                  231
# Model:                        SARIMAX(1, 1, 1)   Log Likelihood                 127.883
# Date:                         Wed, 12 Mar 2025   AIC                           -237.765
# Time:                                 23:38:27   BIC                           -206.823
# Sample:                             01-01-2001   HQIC                          -225.284
#                                   - 03-01-2020
# Covariance Type:                           opg
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Civilian Labor Force (Thousands of people)      0.0001   2.28e-05      6.098      0.000    9.45e-05       0.000
# Hires level (Thousands of people)           -6.732e-05   6.31e-05     -1.067      0.286      -0.000    5.63e-05
# Separations level (Thousands of people)         0.0001   2.82e-05      3.552      0.000    4.49e-05       0.000
# Personal Savings SAAR (Billions of Dollars)  2.602e-06   8.18e-05      0.032      0.975      -0.000       0.000
# Services Employment Index                      -0.0048      0.004     -1.327      0.184      -0.012       0.002
# CPI                                            -0.0186      0.012     -1.611      0.107      -0.041       0.004
# ar.L1                                          -0.1959      0.104     -1.876      0.061      -0.400       0.009
# ma.L1                                          -0.6325      0.097     -6.511      0.000      -0.823      -0.442
# sigma2                                          0.0206      0.002      8.695      0.000       0.016       0.025
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.17   Jarque-Bera (JB):                 1.70
# Prob(Q):                              0.14   Prob(JB):                         0.43
# Heteroskedasticity (H):               1.07   Skew:                            -0.21
# Prob(H) (two-sided):                  0.78   Kurtosis:                         2.97
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# AIC: -237.7653139737028
# BIC: -206.82260019339404
# Mean Absolute Error (MAE): 0.4624149276510987
# Mean Squared Error (MSE): 2.591907519939443
# Root Mean Squared Error (RMSE): 1.6099402224739412
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Residuals
residuals = model_fit.resid

# Plot residuals
plt.figure(figsize=(10, 6))
plt.plot(residuals)
plt.title('Residuals')
plt.axhline(0, linestyle='--', color='red')
plt.show()

# Histogram of residuals
plt.figure(figsize=(10, 6))
plt.hist(residuals, bins=25)
plt.title('Histogram of Residuals')
plt.show()

# Kernel Density Plot
plt.figure(figsize=(10, 6))
residuals.plot(kind='kde')
plt.title('Kernel Density Plot of Residuals')
plt.show()

# ACF and PACF of residuals
fig, ax = plt.subplots(1, 2, figsize=(15, 6))
plot_acf(residuals, ax=ax[0])
plot_pacf(residuals, ax=ax[1])
plt.show()

# Q-Q plot
fig = sm.qqplot(residuals, line='s')
plt.title('Q-Q Plot of Residuals')
plt.show()

# Ljung-Box Test
lb_test = sm.stats.acorr_ljungbox(residuals, lags=[10], return_df=True)
print(lb_test)

# Durbin-Watson test for autocorrelation

dw = durbin_watson(residuals)
print(f"Durbin-Watson statistic: {dw:.2f}")
# Out:
#       lb_stat  lb_pvalue
# 10  13.476353   0.198244
# Durbin-Watson statistic: 2.17

# %%
# Plotting the actual vs. predicted values for visual comparison
plt.figure(figsize=(10, 5))
plt.plot(test_endog.index, test_endog, label='Actual')
plt.plot(test_endog.index, predicted_means, label='Predicted', color='red')
plt.title('Actual vs Predicted')
plt.xlabel('Date')
plt.ylabel('Unemployment Rate')
plt.legend()
plt.show()

# %% [markdown]
# # Removing exogenous variables with less significance

# %%
data_diff1 = data_diff.copy()


# Drop the insignificant columns
data_diff1.drop(['Hires level (Thousands of people)','Separations level (Thousands of people)','Personal Savings SAAR (Billions of Dollars)','CPI'], axis=1, inplace=True)

# %%
# Define the target variable
target_variable = 'Unemployment Rate (Percent)'

# Get the list of all variables except the target variable
exogenous_variables = data_diff1.columns[data_diff1.columns != target_variable]

# %% [markdown]
# # SARIMAX(1,1,1) with 2 exogenous variables

# %%
# Prepare the exogenous variables (features) and the endogenous variable (target)
exog = data_diff1[exogenous_variables]
endog = data_diff1[target_variable]

# Split the data into train and test sets
train_size = int(len(data_diff1) * 0.8)
train_endog = endog[:train_size]
train_exog = exog[:train_size]
test_endog = endog[train_size:]
test_exog = exog[train_size:]

# Fit the ARIMAX model
model2 = SARIMAX(train_endog, exog=train_exog, order=(1,1,1))
model_fit2 = model2.fit()

# Summary of the model
print(model_fit2.summary())

# Predictions
predictions2 = model_fit2.get_forecast(steps=len(test_endog), exog=test_exog)
predicted_means2 = predictions2.predicted_mean
predicted_intervals2 = predictions2.conf_int()

# Calculate the error metrics
mae2 = mean_absolute_error(test_endog, predicted_means2)
mse2 = mean_squared_error(test_endog, predicted_means2)
rmse2 = mse2**0.5

# Output the error metrics
print(f'Mean Absolute Error (MAE): {mae2}')
print(f'Mean Squared Error (MSE): {mse2}')
print(f'Root Mean Squared Error (RMSE): {rmse2}')

# Extract AIC and BIC values
aic = model_fit2.aic
bic = model_fit2.bic
print(f'AIC: {aic}')
print(f'BIC: {bic}')

# Residuals
residuals2 = model_fit2.resid

# Plot residuals
plt.figure(figsize=(10, 6))
plt.plot(residuals2)
plt.title('Residuals')
plt.axhline(0, linestyle='--', color='red')
plt.show()

# Histogram of residuals
plt.figure(figsize=(10, 6))
plt.hist(residuals2, bins=25)
plt.title('Histogram of Residuals')
plt.show()

# Kernel Density Plot
plt.figure(figsize=(10, 6))
residuals2.plot(kind='kde')
plt.title('Kernel Density Plot of Residuals')
plt.show()

# ACF and PACF of residuals
fig, ax = plt.subplots(1, 2, figsize=(15, 6))
plot_acf(residuals2, ax=ax[0])
plot_pacf(residuals2, ax=ax[1])
plt.show()

# Q-Q plot
fig = sm.qqplot(residuals2, line='s')
plt.title('Q-Q Plot of Residuals')
plt.show()

# Ljung-Box Test
lb_test = sm.stats.acorr_ljungbox(residuals2, lags=[10], return_df=True)
print(lb_test)

# Durbin-Watson test for autocorrelation
dw = durbin_watson(residuals2)
print(f"Durbin-Watson statistic: {dw:.2f}")

# Plotting the actual vs. predicted values for visual comparison
plt.figure(figsize=(10, 5))
plt.plot(test_endog.index, test_endog, label='Actual')
plt.plot(test_endog.index, predicted_means2, label='Predicted', color='red')
plt.title('Actual vs Predicted')
plt.xlabel('Date')
plt.ylabel('Unemployment Rate')
plt.legend()
plt.show()
# Out:
#                                     SARIMAX Results
# =======================================================================================
# Dep. Variable:     Unemployment Rate (Percent)   No. Observations:                  231
# Model:                        SARIMAX(1, 1, 1)   Log Likelihood                  99.488
# Date:                         Wed, 12 Mar 2025   AIC                           -188.976
# Time:                                 23:38:28   BIC                           -171.786
# Sample:                             01-01-2001   HQIC                          -182.042
#                                   - 03-01-2020
# Covariance Type:                           opg
# ==============================================================================================================
#                                                  coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Civilian Labor Force (Thousands of people)      7e-05   2.05e-05      3.416      0.001    2.98e-05       0.000
# Services Employment Index                     -0.0018      0.004     -0.436      0.663      -0.010       0.006
# ar.L1                                         -0.2296      0.116     -1.973      0.049      -0.458      -0.002
# ma.L1                                         -0.6220      0.111     -5.600      0.000      -0.840      -0.404
# sigma2                                         0.0259      0.002     12.480      0.000       0.022       0.030
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.03   Jarque-Bera (JB):               634.88
# Prob(Q):                              0.31   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.13   Skew:                             1.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Absolute Error (MAE): 0.6814081372630413
# Mean Squared Error (MSE): 2.4557483950882912
# Root Mean Squared Error (RMSE): 1.5670827658704856
# AIC: -188.9762763600534
# BIC: -171.7858798154374
#      lb_stat  lb_pvalue
# 10  9.708412   0.466437
# Durbin-Watson statistic: 1.95

# %% [markdown]
# # Comparing Statistical models with Machine Learning Models

# %% [markdown]
# # LSTM(Vanilla)

# %% [markdown]
# # without exogenous variables

# %%
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data_diff1[['Unemployment Rate (Percent)']])

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX).reshape(-1, look_back, 1), np.array(dataY).reshape(-1, 1)

look_back = 10
X, y = create_dataset(data_scaled, look_back)

train_size = int(len(X) * 0.8)
trainX, testX = X[:train_size], X[train_size:]
trainY, testY = y[:train_size], y[train_size:]

# Ensure look_back is defined
look_back = trainX.shape[1]  # Time steps

# LSTM without exogenous variables (Univariate)
model = Sequential([
    Input(shape=(look_back, 1)),
    LSTM(50),
    Dense(1)
])
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=0.001)
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2, validation_split=0.2, callbacks=[reduce_lr])


predicted = model.predict(testX)
predicted_rescaled = scaler.inverse_transform(predicted)
testY_rescaled = scaler.inverse_transform(testY)
mse = mean_squared_error(testY_rescaled, predicted_rescaled)
mae = mean_absolute_error(testY_rescaled, predicted_rescaled)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Root Mean Squared Error (RMSE): {rmse}')

plt.figure(figsize=(14, 7))
plt.plot(testY_rescaled, label='Actual', color='blue')
plt.plot(predicted_rescaled, label='Predicted', color='orange')
plt.title('Actual vs Predicted Unemployment Rate')
plt.xlabel('Time Index')
plt.ylabel('Unemployment Rate')
plt.legend()
plt.show()


# Assuming last_sequence is the last part of data_scaled used for forecasting
last_sequence = data_scaled[-look_back:]
current_input = last_sequence.reshape(1, look_back, 1)

predicted_changes = []
for _ in range(12):
    next_difference = model.predict(current_input)
    predicted_changes.append(next_difference.flatten()[0])
    next_difference_reshaped = next_difference.reshape(1, 1, 1)
    current_input = np.append(current_input[:, 1:, :], next_difference_reshaped, axis=1)

predicted_changes_array = np.array(predicted_changes).reshape(-1, 1)
predicted_changes_rescaled = scaler.inverse_transform(predicted_changes_array).flatten()

# Dedifference the predictions
last_actual_value = data['Unemployment Rate (Percent)'].iloc[-1]
dedifferenced_predictions = [last_actual_value + np.sum(predicted_changes_rescaled[:i+1]) for i in range(12)]


print("Dedifferenced forecasted values:")
print(dedifferenced_predictions)
# Out:
# Epoch 1/100
# 178/178 - 3s - 16ms/step - loss: 7.0618e-04 - val_loss: 0.0157 - learning_rate: 0.0100
# Epoch 2/100
# 178/178 - 1s - 5ms/step - loss: 2.4192e-04 - val_loss: 0.0161 - learning_rate: 0.0100
# Epoch 3/100
# 178/178 - 1s - 7ms/step - loss: 2.6518e-04 - val_loss: 0.0166 - learning_rate: 0.0100
# Epoch 4/100
# 178/178 - 1s - 5ms/step - loss: 2.6118e-04 - val_loss: 0.0164 - learning_rate: 0.0100
# Epoch 5/100
# 178/178 - 2s - 10ms/step - loss: 2.7373e-04 - val_loss: 0.0161 - learning_rate: 0.0100
# Epoch 6/100
# 178/178 - 1s - 7ms/step - loss: 2.4735e-04 - val_loss: 0.0158 - learning_rate: 0.0100
# Epoch 7/100
# 178/178 - 1s - 5ms/step - loss: 2.1145e-04 - val_loss: 0.0160 - learning_rate: 0.0100
# Epoch 8/100
# 178/178 - 1s - 5ms/step - loss: 2.4642e-04 - val_loss: 0.0160 - learning_rate: 0.0100
# Epoch 9/100
# 178/178 - 1s - 8ms/step - loss: 2.7080e-04 - val_loss: 0.0156 - learning_rate: 0.0100
# Epoch 10/100
# 178/178 - 1s - 7ms/step - loss: 2.5633e-04 - val_loss: 0.0162 - learning_rate: 0.0100
# Epoch 11/100
# 178/178 - 1s - 7ms/step - loss: 2.5973e-04 - val_loss: 0.0163 - learning_rate: 0.0100
# Epoch 12/100
# 178/178 - 1s - 7ms/step - loss: 2.0934e-04 - val_loss: 0.0157 - learning_rate: 0.0100
# Epoch 13/100
# 178/178 - 1s - 8ms/step - loss: 2.2573e-04 - val_loss: 0.0163 - learning_rate: 0.0100
# Epoch 14/100
# 178/178 - 1s - 5ms/step - loss: 2.6483e-04 - val_loss: 0.0158 - learning_rate: 0.0100
# Epoch 15/100
# 178/178 - 2s - 9ms/step - loss: 2.3479e-04 - val_loss: 0.0156 - learning_rate: 0.0100
# Epoch 16/100
# 178/178 - 2s - 9ms/step - loss: 2.3374e-04 - val_loss: 0.0163 - learning_rate: 0.0100
# Epoch 17/100
# 178/178 - 1s - 5ms/step - loss: 2.1203e-04 - val_loss: 0.0156 - learning_rate: 0.0100
# Epoch 18/100
# 178/178 - 1s - 5ms/step - loss: 2.3224e-04 - val_loss: 0.0158 - learning_rate: 0.0100
# Epoch 19/100
# 178/178 - 1s - 4ms/step - loss: 2.5541e-04 - val_loss: 0.0155 - learning_rate: 0.0100
# Epoch 20/100
# 178/178 - 1s - 8ms/step - loss: 1.8374e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 21/100
# 178/178 - 1s - 5ms/step - loss: 1.8663e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 22/100
# 178/178 - 1s - 5ms/step - loss: 1.8213e-04 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 23/100
# 178/178 - 1s - 7ms/step - loss: 1.8466e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 24/100
# 178/178 - 1s - 7ms/step - loss: 1.8560e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 25/100
# 178/178 - 1s - 5ms/step - loss: 1.8367e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 26/100
# 178/178 - 1s - 5ms/step - loss: 1.8481e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 27/100
# 178/178 - 1s - 7ms/step - loss: 1.8454e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 28/100
# 178/178 - 2s - 9ms/step - loss: 1.8812e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 29/100
# 178/178 - 2s - 10ms/step - loss: 1.8067e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 30/100
# 178/178 - 1s - 5ms/step - loss: 1.7754e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 31/100
# 178/178 - 1s - 7ms/step - loss: 1.8615e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 32/100
# 178/178 - 1s - 5ms/step - loss: 1.7950e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 33/100
# 178/178 - 1s - 8ms/step - loss: 1.7856e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 34/100
# 178/178 - 1s - 6ms/step - loss: 1.8332e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 35/100
# 178/178 - 1s - 8ms/step - loss: 1.8528e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 36/100
# 178/178 - 1s - 5ms/step - loss: 1.8112e-04 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 37/100
# 178/178 - 2s - 10ms/step - loss: 1.8813e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 38/100
# 178/178 - 2s - 11ms/step - loss: 1.7161e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 39/100
# 178/178 - 1s - 8ms/step - loss: 1.8326e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 40/100
# 178/178 - 1s - 7ms/step - loss: 1.8572e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 41/100
# 178/178 - 1s - 5ms/step - loss: 1.7926e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 42/100
# 178/178 - 1s - 5ms/step - loss: 1.7822e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 43/100
# 178/178 - 1s - 7ms/step - loss: 1.7979e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 44/100
# 178/178 - 1s - 7ms/step - loss: 1.7696e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 45/100
# 178/178 - 1s - 5ms/step - loss: 1.7479e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 46/100
# 178/178 - 1s - 8ms/step - loss: 1.7131e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 47/100
# 178/178 - 2s - 8ms/step - loss: 1.7171e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 48/100
# 178/178 - 1s - 7ms/step - loss: 1.8005e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 49/100
# 178/178 - 1s - 5ms/step - loss: 1.7302e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 50/100
# 178/178 - 1s - 7ms/step - loss: 1.7629e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 51/100
# 178/178 - 1s - 5ms/step - loss: 1.7077e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 52/100
# 178/178 - 1s - 5ms/step - loss: 1.7295e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 53/100
# 178/178 - 1s - 6ms/step - loss: 1.7023e-04 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 54/100
# 178/178 - 1s - 7ms/step - loss: 1.7568e-04 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 55/100
# 178/178 - 1s - 5ms/step - loss: 1.7906e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 56/100
# 178/178 - 1s - 6ms/step - loss: 1.6909e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 57/100
# 178/178 - 1s - 5ms/step - loss: 1.7378e-04 - val_loss: 0.0162 - learning_rate: 0.0010
# Epoch 58/100
# 178/178 - 1s - 7ms/step - loss: 1.7611e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 59/100
# 178/178 - 1s - 7ms/step - loss: 1.6674e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 60/100
# 178/178 - 1s - 6ms/step - loss: 1.6322e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 61/100
# 178/178 - 1s - 5ms/step - loss: 1.6840e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 62/100
# 178/178 - 1s - 5ms/step - loss: 1.6848e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 63/100
# 178/178 - 1s - 7ms/step - loss: 1.5582e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 64/100
# 178/178 - 1s - 7ms/step - loss: 1.6658e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 65/100
# 178/178 - 1s - 5ms/step - loss: 1.6581e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 66/100
# 178/178 - 1s - 7ms/step - loss: 1.6697e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 67/100
# 178/178 - 1s - 6ms/step - loss: 1.7433e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 68/100
# 178/178 - 1s - 7ms/step - loss: 1.6585e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 69/100
# 178/178 - 1s - 6ms/step - loss: 1.6548e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 70/100
# 178/178 - 2s - 9ms/step - loss: 1.5623e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 71/100
# 178/178 - 2s - 10ms/step - loss: 1.6318e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 72/100
# 178/178 - 1s - 4ms/step - loss: 1.6473e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 73/100
# 178/178 - 1s - 5ms/step - loss: 1.6741e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 74/100
# 178/178 - 1s - 4ms/step - loss: 1.6495e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 75/100
# 178/178 - 1s - 7ms/step - loss: 1.6879e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 76/100
# 178/178 - 1s - 8ms/step - loss: 1.6060e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 77/100
# 178/178 - 1s - 4ms/step - loss: 1.7178e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 78/100
# 178/178 - 1s - 8ms/step - loss: 1.6294e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 79/100
# 178/178 - 1s - 8ms/step - loss: 1.6510e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 80/100
# 178/178 - 2s - 9ms/step - loss: 1.5815e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 81/100
# 178/178 - 1s - 7ms/step - loss: 1.6083e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 82/100
# 178/178 - 1s - 5ms/step - loss: 1.5639e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 83/100
# 178/178 - 1s - 5ms/step - loss: 1.7435e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 84/100
# 178/178 - 1s - 8ms/step - loss: 1.6215e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 85/100
# 178/178 - 1s - 5ms/step - loss: 1.5991e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 86/100
# 178/178 - 1s - 7ms/step - loss: 1.7109e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 87/100
# 178/178 - 1s - 7ms/step - loss: 1.6200e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 88/100
# 178/178 - 1s - 5ms/step - loss: 1.5669e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 89/100
# 178/178 - 1s - 5ms/step - loss: 1.5799e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 90/100
# 178/178 - 1s - 7ms/step - loss: 1.6220e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 91/100
# 178/178 - 1s - 8ms/step - loss: 1.7100e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 92/100
# 178/178 - 2s - 9ms/step - loss: 1.5926e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 93/100
# 178/178 - 1s - 5ms/step - loss: 1.6156e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 94/100
# 178/178 - 1s - 5ms/step - loss: 1.5266e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 95/100
# 178/178 - 1s - 5ms/step - loss: 1.5695e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 96/100
# 178/178 - 1s - 5ms/step - loss: 1.6417e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 97/100
# 178/178 - 1s - 6ms/step - loss: 1.5609e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 98/100
# 178/178 - 1s - 5ms/step - loss: 1.6880e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 99/100
# 178/178 - 1s - 4ms/step - loss: 1.5389e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 100/100
# 178/178 - 1s - 7ms/step - loss: 1.6041e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# Mean Squared Error (MSE): 0.48156008320225246
# Mean Absolute Error (MAE): 0.3014379818715887
# Root Mean Squared Error (RMSE): 0.6939453027452902
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Dedifferenced forecasted values:
# [3.951049230992794, 3.8892661929130554, 3.821974605321884, 3.7517099380493164, 3.680294156074524, 3.6070762872695923, 3.531506061553955, 3.4566359519958496, 3.3843343257904053, 3.310421586036682, 3.235500395298004, 3.1608933210372925]

# %% [markdown]
# # with exogenous variables

# %%
# Data Preparation
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data_diff1[['Unemployment Rate (Percent)', 'Civilian Labor Force (Thousands of people)', 'Services Employment Index']])

# Create dataset for LSTM considering all features
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY).reshape(-1, 1)

look_back = 10
X, y = create_dataset(data_scaled, look_back)

# Split data into train and test sets
train_size = int(len(X) * 0.8)
trainX, testX = X[:train_size], X[train_size:]
trainY, testY = y[:train_size], y[train_size:]

# Ensure look_back and num_features are defined
look_back = trainX.shape[1]  # Time steps
num_features = trainX.shape[2]  # Number of features

# LSTM Model with multiple features
model = Sequential([
    Input(shape=(look_back, num_features)),
    LSTM(50),
    Dense(1)
])
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=0.001)
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# Making predictions
predicted_values = model.predict(testX)

# Revert scaling
testY_rescaled = scaler.inverse_transform(np.hstack([testY, np.zeros((len(testY), 2))]))[:, 0]  # Only reverse scale target
predicted_values_rescaled = scaler.inverse_transform(np.hstack([predicted_values, np.zeros((len(predicted_values), 2))]))[:, 0]

# Calculate error metrics
mse = mean_squared_error(testY_rescaled, predicted_values_rescaled)
mae = mean_absolute_error(testY_rescaled, predicted_values_rescaled)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Root Mean Squared Error (RMSE): {rmse}')

# Plotting actual vs predicted values
plt.figure(figsize=(14, 7))
plt.plot(testY_rescaled, label='Actual', color='blue')
plt.plot(predicted_values_rescaled, label='Predicted LSTM with Exogenous', color='orange')
plt.title('Actual vs Predicted Unemployment Rates')
plt.xlabel('Time Index')
plt.ylabel('Unemployment Rate (Percent)')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 222/222 - 3s - 15ms/step - loss: 0.0050
# Epoch 2/100
# 222/222 - 1s - 4ms/step - loss: 0.0039
# Epoch 3/100
# 222/222 - 1s - 5ms/step - loss: 0.0037
# Epoch 4/100
# 222/222 - 1s - 6ms/step - loss: 0.0038
# Epoch 5/100
# 222/222 - 1s - 5ms/step - loss: 0.0036
# Epoch 6/100
# 222/222 - 1s - 6ms/step - loss: 0.0035
# Epoch 7/100
# 222/222 - 1s - 4ms/step - loss: 0.0035
# Epoch 8/100
# 222/222 - 1s - 4ms/step - loss: 0.0035
# Epoch 9/100
# 222/222 - 1s - 6ms/step - loss: 0.0035
# Epoch 10/100
# 222/222 - 2s - 7ms/step - loss: 0.0035
# Epoch 11/100
# 222/222 - 1s - 5ms/step - loss: 0.0035
# Epoch 12/100
# 222/222 - 1s - 4ms/step - loss: 0.0035
# Epoch 13/100
# 222/222 - 1s - 5ms/step - loss: 0.0035
# Epoch 14/100
# 222/222 - 1s - 4ms/step - loss: 0.0035
# Epoch 15/100
# 222/222 - 1s - 6ms/step - loss: 0.0034
# Epoch 16/100
# 222/222 - 1s - 4ms/step - loss: 0.0032
# Epoch 17/100
# 222/222 - 1s - 6ms/step - loss: 0.0039
# Epoch 18/100
# 222/222 - 1s - 6ms/step - loss: 0.0034
# Epoch 19/100
# 222/222 - 1s - 3ms/step - loss: 0.0035
# Epoch 20/100
# 222/222 - 2s - 7ms/step - loss: 0.0033
# Epoch 21/100
# 222/222 - 2s - 8ms/step - loss: 0.0036
# Epoch 22/100
# 222/222 - 1s - 5ms/step - loss: 0.0034
# Epoch 23/100
# 222/222 - 1s - 5ms/step - loss: 0.0032
# Epoch 24/100
# 222/222 - 1s - 5ms/step - loss: 0.0033
# Epoch 25/100
# 222/222 - 1s - 4ms/step - loss: 0.0033
# Epoch 26/100
# 222/222 - 1s - 4ms/step - loss: 0.0031
# Epoch 27/100
# 222/222 - 1s - 4ms/step - loss: 0.0031
# Epoch 28/100
# 222/222 - 1s - 6ms/step - loss: 0.0032
# Epoch 29/100
# 222/222 - 1s - 5ms/step - loss: 0.0029
# Epoch 30/100
# 222/222 - 1s - 5ms/step - loss: 0.0029
# Epoch 31/100
# 222/222 - 2s - 9ms/step - loss: 0.0030
# Epoch 32/100
# 222/222 - 2s - 9ms/step - loss: 0.0029
# Epoch 33/100
# 222/222 - 1s - 5ms/step - loss: 0.0028
# Epoch 34/100
# 222/222 - 1s - 6ms/step - loss: 0.0023
# Epoch 35/100
# 222/222 - 1s - 4ms/step - loss: 0.0027
# Epoch 36/100
# 222/222 - 1s - 5ms/step - loss: 0.0026
# Epoch 37/100
# 222/222 - 1s - 6ms/step - loss: 0.0024
# Epoch 38/100
# 222/222 - 1s - 3ms/step - loss: 0.0025
# Epoch 39/100
# 222/222 - 1s - 6ms/step - loss: 0.0025
# Epoch 40/100
# 222/222 - 2s - 8ms/step - loss: 0.0025
# Epoch 41/100
# 222/222 - 2s - 7ms/step - loss: 0.0022
# Epoch 42/100
# 222/222 - 1s - 5ms/step - loss: 0.0021
# Epoch 43/100
# 222/222 - 1s - 5ms/step - loss: 0.0021
# Epoch 44/100
# 222/222 - 1s - 4ms/step - loss: 0.0022
# Epoch 45/100
# 222/222 - 1s - 5ms/step - loss: 0.0019
# Epoch 46/100
# 222/222 - 1s - 3ms/step - loss: 0.0019
# Epoch 47/100
# 222/222 - 1s - 3ms/step - loss: 0.0022
# Epoch 48/100
# 222/222 - 1s - 6ms/step - loss: 0.0017
# Epoch 49/100
# 222/222 - 1s - 6ms/step - loss: 0.0018
# Epoch 50/100
# 222/222 - 1s - 5ms/step - loss: 0.0015
# Epoch 51/100
# 222/222 - 2s - 7ms/step - loss: 0.0016
# Epoch 52/100
# 222/222 - 2s - 7ms/step - loss: 0.0014
# Epoch 53/100
# 222/222 - 2s - 9ms/step - loss: 0.0017
# Epoch 54/100
# 222/222 - 1s - 3ms/step - loss: 0.0012
# Epoch 55/100
# 222/222 - 1s - 4ms/step - loss: 0.0014
# Epoch 56/100
# 222/222 - 1s - 6ms/step - loss: 7.8008e-04
# Epoch 57/100
# 222/222 - 1s - 6ms/step - loss: 0.0014
# Epoch 58/100
# 222/222 - 1s - 3ms/step - loss: 0.0015
# Epoch 59/100
# 222/222 - 1s - 4ms/step - loss: 8.8423e-04
# Epoch 60/100
# 222/222 - 1s - 5ms/step - loss: 0.0013
# Epoch 61/100
# 222/222 - 1s - 5ms/step - loss: 9.3755e-04
# Epoch 62/100
# 222/222 - 2s - 8ms/step - loss: 0.0011
# Epoch 63/100
# 222/222 - 1s - 6ms/step - loss: 9.1604e-04
# Epoch 64/100
# 222/222 - 2s - 9ms/step - loss: 0.0012
# Epoch 65/100
# 222/222 - 1s - 3ms/step - loss: 8.6917e-04
# Epoch 66/100
# 222/222 - 1s - 3ms/step - loss: 8.2233e-04
# Epoch 67/100
# 222/222 - 1s - 4ms/step - loss: 9.5748e-04
# Epoch 68/100
# 222/222 - 1s - 4ms/step - loss: 6.3060e-04
# Epoch 69/100
# 222/222 - 1s - 5ms/step - loss: 8.6601e-04
# Epoch 70/100
# 222/222 - 1s - 4ms/step - loss: 6.8850e-04
# Epoch 71/100
# 222/222 - 1s - 4ms/step - loss: 5.5811e-04
# Epoch 72/100
# 222/222 - 1s - 4ms/step - loss: 7.4249e-04
# Epoch 73/100
# 222/222 - 1s - 4ms/step - loss: 4.5921e-04
# Epoch 74/100
# 222/222 - 2s - 8ms/step - loss: 0.0010
# Epoch 75/100
# 222/222 - 1s - 5ms/step - loss: 0.0011
# Epoch 76/100
# 222/222 - 1s - 4ms/step - loss: 5.8354e-04
# Epoch 77/100
# 222/222 - 1s - 6ms/step - loss: 6.4785e-04
# Epoch 78/100
# 222/222 - 1s - 4ms/step - loss: 5.9848e-04
# Epoch 79/100
# 222/222 - 1s - 5ms/step - loss: 9.4530e-04
# Epoch 80/100
# 222/222 - 1s - 5ms/step - loss: 5.9457e-04
# Epoch 81/100
# 222/222 - 1s - 6ms/step - loss: 4.1715e-04
# Epoch 82/100
# 222/222 - 1s - 6ms/step - loss: 0.0015
# Epoch 83/100
# 222/222 - 1s - 5ms/step - loss: 5.8539e-04
# Epoch 84/100
# 222/222 - 1s - 6ms/step - loss: 4.8290e-04
# Epoch 85/100
# 222/222 - 2s - 9ms/step - loss: 5.9166e-04
# Epoch 86/100
# 222/222 - 1s - 4ms/step - loss: 0.0022
# Epoch 87/100
# 222/222 - 1s - 6ms/step - loss: 6.7574e-04
# Epoch 88/100
# 222/222 - 1s - 6ms/step - loss: 3.0622e-04
# Epoch 89/100
# 222/222 - 1s - 4ms/step - loss: 0.0013
# Epoch 90/100
# 222/222 - 1s - 6ms/step - loss: 5.7459e-04
# Epoch 91/100
# 222/222 - 1s - 6ms/step - loss: 6.5550e-04
# Epoch 92/100
# 222/222 - 1s - 6ms/step - loss: 6.4574e-04
# Epoch 93/100
# 222/222 - 1s - 6ms/step - loss: 0.0026
# Epoch 94/100
# 222/222 - 2s - 8ms/step - loss: 9.9072e-04
# Epoch 95/100
# 222/222 - 2s - 9ms/step - loss: 5.0530e-04
# Epoch 96/100
# 222/222 - 1s - 5ms/step - loss: 9.4941e-04
# Epoch 97/100
# 222/222 - 1s - 6ms/step - loss: 4.9975e-04
# Epoch 98/100
# 222/222 - 1s - 6ms/step - loss: 6.9082e-04
# Epoch 99/100
# 222/222 - 1s - 4ms/step - loss: 5.4545e-04
# Epoch 100/100
# 222/222 - 1s - 4ms/step - loss: 6.4727e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# Mean Squared Error (MSE): 325.14460849278265
# Mean Absolute Error (MAE): 2.6640135142952204
# Root Mean Squared Error (RMSE): 18.031766649243846

# %% [markdown]
# # Bi-LSTM

# %% [markdown]
# # Without exogenous variables

# %%
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data_diff1[['Unemployment Rate (Percent)']])

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX).reshape(-1, look_back, 1), np.array(dataY).reshape(-1, 1)

look_back = 10
X, y = create_dataset(data_scaled, look_back)

train_size = int(len(X) * 0.8)
trainX, testX = X[:train_size], X[train_size:]
trainY, testY = y[:train_size], y[train_size:]

# Ensure look_back is defined
look_back = trainX.shape[1]  # Time steps

# Bi-LSTM without exogenous variables (Univariate)
model = Sequential([
    Input(shape=(look_back, 1)),
    Bidirectional(LSTM(50)),
    Dense(1)
])
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=0.001)
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2, validation_split=0.2, callbacks=[reduce_lr])


predicted = model.predict(testX)
predicted_rescaled = scaler.inverse_transform(predicted)
testY_rescaled = scaler.inverse_transform(testY)
mse = mean_squared_error(testY_rescaled, predicted_rescaled)
mae = mean_absolute_error(testY_rescaled, predicted_rescaled)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Root Mean Squared Error (RMSE): {rmse}')

plt.figure(figsize=(14, 7))
plt.plot(testY_rescaled, label='Actual', color='blue')
plt.plot(predicted_rescaled, label='Predicted', color='orange')
plt.title('Actual vs Predicted Unemployment Rates')
plt.xlabel('Time Index')
plt.ylabel('Unemployment Rate')
plt.legend()
plt.show()


# Assuming last_sequence is the last part of data_scaled used for forecasting
last_sequence = data_scaled[-look_back:]
current_input = last_sequence.reshape(1, look_back, 1)

predicted_changes = []
for _ in range(12):
    next_difference = model.predict(current_input)
    predicted_changes.append(next_difference.flatten()[0])
    next_difference_reshaped = next_difference.reshape(1, 1, 1)
    current_input = np.append(current_input[:, 1:, :], next_difference_reshaped, axis=1)

predicted_changes_array = np.array(predicted_changes).reshape(-1, 1)
predicted_changes_rescaled = scaler.inverse_transform(predicted_changes_array).flatten()

# Dedifference the predictions
last_actual_value = data['Unemployment Rate (Percent)'].iloc[-1]
dedifferenced_predictions = [last_actual_value + np.sum(predicted_changes_rescaled[:i+1]) for i in range(12)]


print("Dedifferenced forecasted values:")
print(dedifferenced_predictions)
# Out:
# Epoch 1/100
# 178/178 - 6s - 32ms/step - loss: 6.4010e-04 - val_loss: 0.0168 - learning_rate: 0.0100
# Epoch 2/100
# 178/178 - 1s - 6ms/step - loss: 4.2284e-04 - val_loss: 0.0155 - learning_rate: 0.0100
# Epoch 3/100
# 178/178 - 1s - 7ms/step - loss: 2.7376e-04 - val_loss: 0.0155 - learning_rate: 0.0100
# Epoch 4/100
# 178/178 - 1s - 7ms/step - loss: 2.8779e-04 - val_loss: 0.0157 - learning_rate: 0.0100
# Epoch 5/100
# 178/178 - 1s - 7ms/step - loss: 2.6784e-04 - val_loss: 0.0155 - learning_rate: 0.0100
# Epoch 6/100
# 178/178 - 1s - 6ms/step - loss: 2.3490e-04 - val_loss: 0.0156 - learning_rate: 0.0100
# Epoch 7/100
# 178/178 - 1s - 8ms/step - loss: 2.4639e-04 - val_loss: 0.0155 - learning_rate: 0.0100
# Epoch 8/100
# 178/178 - 2s - 9ms/step - loss: 2.3673e-04 - val_loss: 0.0158 - learning_rate: 0.0100
# Epoch 9/100
# 178/178 - 2s - 11ms/step - loss: 2.4207e-04 - val_loss: 0.0157 - learning_rate: 0.0100
# Epoch 10/100
# 178/178 - 1s - 7ms/step - loss: 2.4196e-04 - val_loss: 0.0156 - learning_rate: 0.0100
# Epoch 11/100
# 178/178 - 1s - 7ms/step - loss: 2.1214e-04 - val_loss: 0.0156 - learning_rate: 0.0100
# Epoch 12/100
# 178/178 - 1s - 7ms/step - loss: 2.5223e-04 - val_loss: 0.0157 - learning_rate: 0.0100
# Epoch 13/100
# 178/178 - 1s - 7ms/step - loss: 1.8679e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 14/100
# 178/178 - 1s - 7ms/step - loss: 1.8724e-04 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 15/100
# 178/178 - 1s - 6ms/step - loss: 1.8665e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 16/100
# 178/178 - 1s - 7ms/step - loss: 1.8274e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 17/100
# 178/178 - 1s - 7ms/step - loss: 1.8769e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 18/100
# 178/178 - 2s - 10ms/step - loss: 1.8810e-04 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 19/100
# 178/178 - 2s - 12ms/step - loss: 1.8125e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 20/100
# 178/178 - 2s - 13ms/step - loss: 1.7271e-04 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 21/100
# 178/178 - 1s - 7ms/step - loss: 1.8138e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 22/100
# 178/178 - 1s - 8ms/step - loss: 1.7653e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 23/100
# 178/178 - 1s - 7ms/step - loss: 1.8178e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 24/100
# 178/178 - 1s - 7ms/step - loss: 1.8549e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 25/100
# 178/178 - 1s - 7ms/step - loss: 1.8801e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 26/100
# 178/178 - 2s - 11ms/step - loss: 1.8022e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 27/100
# 178/178 - 1s - 8ms/step - loss: 1.8631e-04 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 28/100
# 178/178 - 1s - 7ms/step - loss: 1.7483e-04 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 29/100
# 178/178 - 1s - 7ms/step - loss: 1.9076e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 30/100
# 178/178 - 1s - 6ms/step - loss: 1.8125e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 31/100
# 178/178 - 1s - 6ms/step - loss: 1.7797e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 32/100
# 178/178 - 1s - 8ms/step - loss: 1.7478e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 33/100
# 178/178 - 1s - 7ms/step - loss: 1.8586e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 34/100
# 178/178 - 1s - 6ms/step - loss: 1.8291e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 35/100
# 178/178 - 2s - 10ms/step - loss: 1.7868e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 36/100
# 178/178 - 2s - 12ms/step - loss: 1.7561e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 37/100
# 178/178 - 1s - 7ms/step - loss: 1.6877e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 38/100
# 178/178 - 1s - 6ms/step - loss: 1.7821e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 39/100
# 178/178 - 1s - 7ms/step - loss: 1.8161e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 40/100
# 178/178 - 1s - 7ms/step - loss: 1.7018e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 41/100
# 178/178 - 1s - 7ms/step - loss: 1.8666e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 42/100
# 178/178 - 1s - 7ms/step - loss: 1.7480e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 43/100
# 178/178 - 1s - 8ms/step - loss: 1.7127e-04 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 44/100
# 178/178 - 3s - 15ms/step - loss: 1.7608e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 45/100
# 178/178 - 1s - 6ms/step - loss: 1.7448e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 46/100
# 178/178 - 1s - 8ms/step - loss: 1.8170e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 47/100
# 178/178 - 2s - 14ms/step - loss: 1.7621e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 48/100
# 178/178 - 1s - 6ms/step - loss: 1.6676e-04 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 49/100
# 178/178 - 1s - 7ms/step - loss: 1.6732e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 50/100
# 178/178 - 1s - 6ms/step - loss: 1.6772e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 51/100
# 178/178 - 2s - 8ms/step - loss: 1.7517e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 52/100
# 178/178 - 2s - 14ms/step - loss: 1.7509e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 53/100
# 178/178 - 1s - 7ms/step - loss: 1.6651e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 54/100
# 178/178 - 1s - 6ms/step - loss: 1.8877e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 55/100
# 178/178 - 1s - 6ms/step - loss: 1.7892e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 56/100
# 178/178 - 1s - 7ms/step - loss: 1.6894e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 57/100
# 178/178 - 1s - 7ms/step - loss: 1.7527e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 58/100
# 178/178 - 1s - 7ms/step - loss: 1.6551e-04 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 59/100
# 178/178 - 1s - 7ms/step - loss: 1.7167e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 60/100
# 178/178 - 2s - 11ms/step - loss: 1.6024e-04 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 61/100
# 178/178 - 2s - 10ms/step - loss: 1.6879e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 62/100
# 178/178 - 2s - 11ms/step - loss: 1.6485e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 63/100
# 178/178 - 1s - 7ms/step - loss: 1.7276e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 64/100
# 178/178 - 1s - 8ms/step - loss: 1.6472e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 65/100
# 178/178 - 1s - 7ms/step - loss: 1.8221e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 66/100
# 178/178 - 1s - 7ms/step - loss: 1.6601e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 67/100
# 178/178 - 1s - 7ms/step - loss: 1.6664e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 68/100
# 178/178 - 3s - 19ms/step - loss: 1.6804e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 69/100
# 178/178 - 1s - 8ms/step - loss: 1.7465e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 70/100
# 178/178 - 2s - 13ms/step - loss: 1.6732e-04 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 71/100
# 178/178 - 1s - 7ms/step - loss: 1.7339e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 72/100
# 178/178 - 1s - 8ms/step - loss: 1.6353e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 73/100
# 178/178 - 2s - 12ms/step - loss: 1.7310e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 74/100
# 178/178 - 1s - 8ms/step - loss: 1.6820e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 75/100
# 178/178 - 2s - 12ms/step - loss: 1.6484e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 76/100
# 178/178 - 2s - 9ms/step - loss: 1.6959e-04 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 77/100
# 178/178 - 2s - 11ms/step - loss: 1.7273e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 78/100
# 178/178 - 1s - 6ms/step - loss: 1.6522e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 79/100
# 178/178 - 1s - 8ms/step - loss: 1.5946e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 80/100
# 178/178 - 1s - 8ms/step - loss: 1.6848e-04 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 81/100
# 178/178 - 1s - 7ms/step - loss: 1.6360e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 82/100
# 178/178 - 1s - 6ms/step - loss: 1.6623e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 83/100
# 178/178 - 2s - 10ms/step - loss: 1.6803e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 84/100
# 178/178 - 2s - 12ms/step - loss: 1.6707e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 85/100
# 178/178 - 1s - 7ms/step - loss: 1.6756e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 86/100
# 178/178 - 1s - 7ms/step - loss: 1.5759e-04 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 87/100
# 178/178 - 1s - 7ms/step - loss: 1.5975e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 88/100
# 178/178 - 3s - 14ms/step - loss: 1.6649e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 89/100
# 178/178 - 2s - 13ms/step - loss: 1.6672e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 90/100
# 178/178 - 2s - 11ms/step - loss: 1.6221e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 91/100
# 178/178 - 2s - 11ms/step - loss: 1.6272e-04 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 92/100
# 178/178 - 1s - 7ms/step - loss: 1.7650e-04 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 93/100
# 178/178 - 1s - 7ms/step - loss: 1.6089e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 94/100
# 178/178 - 1s - 7ms/step - loss: 1.6603e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 95/100
# 178/178 - 1s - 8ms/step - loss: 1.6247e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 96/100
# 178/178 - 1s - 7ms/step - loss: 1.6559e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 97/100
# 178/178 - 3s - 16ms/step - loss: 1.6184e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 98/100
# 178/178 - 2s - 11ms/step - loss: 1.6327e-04 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 99/100
# 178/178 - 2s - 9ms/step - loss: 1.5981e-04 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 100/100
# 178/178 - 1s - 8ms/step - loss: 1.6037e-04 - val_loss: 0.0158 - learning_rate: 0.0010
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 386ms/step
# Mean Squared Error (MSE): 0.5439051132173521
# Mean Absolute Error (MAE): 0.31511652743793095
# Root Mean Squared Error (RMSE): 0.7374992292994971
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Dedifferenced forecasted values:
# [4.007796379737556, 4.006482717115432, 4.00593359163031, 4.010384371504188, 4.020262762904167, 4.034379903227091, 4.054415445774794, 4.081361673772335, 4.109881468117237, 4.137615889310837, 4.166762784123421, 4.197564169764519]

# %% [markdown]
# # With exogenous variables

# %%
# Data Preparation
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data_diff1[['Unemployment Rate (Percent)', 'Civilian Labor Force (Thousands of people)', 'Services Employment Index']])

# Create dataset for Bi-LSTM considering all features
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY).reshape(-1, 1)

look_back = 10
X, y = create_dataset(data_scaled, look_back)

# Split data into train and test sets
train_size = int(len(X) * 0.8)
trainX, testX = X[:train_size], X[train_size:]
trainY, testY = y[:train_size], y[train_size:]

# Ensure look_back and num_features are defined
look_back = trainX.shape[1]  # Time steps
num_features = trainX.shape[2]  # Number of features

# Bi-LSTM Model with multiple features
model = Sequential([
    Input(shape=(look_back, num_features)),
    Bidirectional(LSTM(50)),
    Dense(1)
])
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=0.001)
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# Making predictions
predicted_values = model.predict(testX)

# Revert scaling
testY_rescaled = scaler.inverse_transform(np.hstack([testY, np.zeros((len(testY), 2))]))[:, 0]  # Only reverse scale target
predicted_values_rescaled = scaler.inverse_transform(np.hstack([predicted_values, np.zeros((len(predicted_values), 2))]))[:, 0]

# Calculate error metrics
mse = mean_squared_error(testY_rescaled, predicted_values_rescaled)
mae = mean_absolute_error(testY_rescaled, predicted_values_rescaled)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Root Mean Squared Error (RMSE): {rmse}')

# Plotting actual vs predicted values
plt.figure(figsize=(14, 7))
plt.plot(testY_rescaled, label='Actual', color='blue')
plt.plot(predicted_values_rescaled, label='Predicted LSTM with Exogenous', color='orange')
plt.title('Actual vs Predicted Unemployment Rates')
plt.xlabel('Time Index')
plt.ylabel('Unemployment Rate (Percent)')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 222/222 - 4s - 19ms/step - loss: 0.0084
# Epoch 2/100
# 222/222 - 3s - 11ms/step - loss: 0.0041
# Epoch 3/100
# 222/222 - 2s - 11ms/step - loss: 0.0038
# Epoch 4/100
# 222/222 - 1s - 6ms/step - loss: 0.0038
# Epoch 5/100
# 222/222 - 2s - 11ms/step - loss: 0.0036
# Epoch 6/100
# 222/222 - 1s - 5ms/step - loss: 0.0037
# Epoch 7/100
# 222/222 - 1s - 5ms/step - loss: 0.0036
# Epoch 8/100
# 222/222 - 2s - 7ms/step - loss: 0.0036
# Epoch 9/100
# 222/222 - 3s - 12ms/step - loss: 0.0036
# Epoch 10/100
# 222/222 - 1s - 6ms/step - loss: 0.0036
# Epoch 11/100
# 222/222 - 1s - 6ms/step - loss: 0.0036
# Epoch 12/100
# 222/222 - 2s - 11ms/step - loss: 0.0035
# Epoch 13/100
# 222/222 - 2s - 11ms/step - loss: 0.0035
# Epoch 14/100
# 222/222 - 1s - 6ms/step - loss: 0.0036
# Epoch 15/100
# 222/222 - 2s - 11ms/step - loss: 0.0036
# Epoch 16/100
# 222/222 - 1s - 7ms/step - loss: 0.0035
# Epoch 17/100
# 222/222 - 1s - 6ms/step - loss: 0.0035
# Epoch 18/100
# 222/222 - 1s - 6ms/step - loss: 0.0035
# Epoch 19/100
# 222/222 - 2s - 11ms/step - loss: 0.0036
# Epoch 20/100
# 222/222 - 1s - 7ms/step - loss: 0.0033
# Epoch 21/100
# 222/222 - 1s - 6ms/step - loss: 0.0037
# Epoch 22/100
# 222/222 - 1s - 7ms/step - loss: 0.0033
# Epoch 23/100
# 222/222 - 2s - 10ms/step - loss: 0.0037
# Epoch 24/100
# 222/222 - 1s - 5ms/step - loss: 0.0035
# Epoch 25/100
# 222/222 - 1s - 6ms/step - loss: 0.0035
# Epoch 26/100
# 222/222 - 1s - 6ms/step - loss: 0.0035
# Epoch 27/100
# 222/222 - 1s - 6ms/step - loss: 0.0035
# Epoch 28/100
# 222/222 - 1s - 6ms/step - loss: 0.0036
# Epoch 29/100
# 222/222 - 2s - 11ms/step - loss: 0.0035
# Epoch 30/100
# 222/222 - 1s - 7ms/step - loss: 0.0035
# Epoch 31/100
# 222/222 - 2s - 11ms/step - loss: 0.0033
# Epoch 32/100
# 222/222 - 2s - 7ms/step - loss: 0.0037
# Epoch 33/100
# 222/222 - 1s - 6ms/step - loss: 0.0035
# Epoch 34/100
# 222/222 - 1s - 6ms/step - loss: 0.0034
# Epoch 35/100
# 222/222 - 1s - 6ms/step - loss: 0.0035
# Epoch 36/100
# 222/222 - 1s - 6ms/step - loss: 0.0035
# Epoch 37/100
# 222/222 - 1s - 6ms/step - loss: 0.0034
# Epoch 38/100
# 222/222 - 1s - 5ms/step - loss: 0.0035
# Epoch 39/100
# 222/222 - 2s - 8ms/step - loss: 0.0034
# Epoch 40/100
# 222/222 - 2s - 10ms/step - loss: 0.0034
# Epoch 41/100
# 222/222 - 2s - 10ms/step - loss: 0.0033
# Epoch 42/100
# 222/222 - 1s - 6ms/step - loss: 0.0030
# Epoch 43/100
# 222/222 - 1s - 6ms/step - loss: 0.0033
# Epoch 44/100
# 222/222 - 1s - 6ms/step - loss: 0.0029
# Epoch 45/100
# 222/222 - 2s - 11ms/step - loss: 0.0028
# Epoch 46/100
# 222/222 - 2s - 9ms/step - loss: 0.0030
# Epoch 47/100
# 222/222 - 2s - 9ms/step - loss: 0.0027
# Epoch 48/100
# 222/222 - 2s - 10ms/step - loss: 0.0026
# Epoch 49/100
# 222/222 - 1s - 6ms/step - loss: 0.0028
# Epoch 50/100
# 222/222 - 1s - 5ms/step - loss: 0.0026
# Epoch 51/100
# 222/222 - 1s - 5ms/step - loss: 0.0026
# Epoch 52/100
# 222/222 - 1s - 7ms/step - loss: 0.0023
# Epoch 53/100
# 222/222 - 1s - 6ms/step - loss: 0.0025
# Epoch 54/100
# 222/222 - 3s - 13ms/step - loss: 0.0023
# Epoch 55/100
# 222/222 - 2s - 9ms/step - loss: 0.0023
# Epoch 56/100
# 222/222 - 1s - 6ms/step - loss: 0.0022
# Epoch 57/100
# 222/222 - 1s - 6ms/step - loss: 0.0022
# Epoch 58/100
# 222/222 - 1s - 6ms/step - loss: 0.0021
# Epoch 59/100
# 222/222 - 1s - 5ms/step - loss: 0.0018
# Epoch 60/100
# 222/222 - 1s - 5ms/step - loss: 0.0018
# Epoch 61/100
# 222/222 - 1s - 6ms/step - loss: 0.0017
# Epoch 62/100
# 222/222 - 2s - 10ms/step - loss: 0.0016
# Epoch 63/100
# 222/222 - 1s - 6ms/step - loss: 0.0018
# Epoch 64/100
# 222/222 - 2s - 10ms/step - loss: 0.0017
# Epoch 65/100
# 222/222 - 1s - 6ms/step - loss: 0.0016
# Epoch 66/100
# 222/222 - 1s - 6ms/step - loss: 0.0013
# Epoch 67/100
# 222/222 - 1s - 6ms/step - loss: 0.0013
# Epoch 68/100
# 222/222 - 2s - 11ms/step - loss: 0.0014
# Epoch 69/100
# 222/222 - 2s - 8ms/step - loss: 8.7055e-04
# Epoch 70/100
# 222/222 - 2s - 10ms/step - loss: 0.0012
# Epoch 71/100
# 222/222 - 2s - 10ms/step - loss: 0.0012
# Epoch 72/100
# 222/222 - 1s - 6ms/step - loss: 0.0010
# Epoch 73/100
# 222/222 - 3s - 11ms/step - loss: 0.0011
# Epoch 74/100
# 222/222 - 1s - 5ms/step - loss: 0.0012
# Epoch 75/100
# 222/222 - 1s - 5ms/step - loss: 9.9432e-04
# Epoch 76/100
# 222/222 - 2s - 10ms/step - loss: 0.0013
# Epoch 77/100
# 222/222 - 2s - 8ms/step - loss: 0.0010
# Epoch 78/100
# 222/222 - 1s - 6ms/step - loss: 0.0011
# Epoch 79/100
# 222/222 - 1s - 6ms/step - loss: 5.2261e-04
# Epoch 80/100
# 222/222 - 3s - 11ms/step - loss: 0.0012
# Epoch 81/100
# 222/222 - 3s - 12ms/step - loss: 8.1031e-04
# Epoch 82/100
# 222/222 - 3s - 14ms/step - loss: 7.2589e-04
# Epoch 83/100
# 222/222 - 1s - 5ms/step - loss: 7.4571e-04
# Epoch 84/100
# 222/222 - 1s - 5ms/step - loss: 7.5606e-04
# Epoch 85/100
# 222/222 - 2s - 7ms/step - loss: 7.7257e-04
# Epoch 86/100
# 222/222 - 2s - 10ms/step - loss: 8.2569e-04
# Epoch 87/100
# 222/222 - 1s - 6ms/step - loss: 7.6017e-04
# Epoch 88/100
# 222/222 - 3s - 12ms/step - loss: 6.8273e-04
# Epoch 89/100
# 222/222 - 2s - 10ms/step - loss: 4.3262e-04
# Epoch 90/100
# 222/222 - 1s - 7ms/step - loss: 7.8251e-04
# Epoch 91/100
# 222/222 - 2s - 10ms/step - loss: 6.0580e-04
# Epoch 92/100
# 222/222 - 1s - 5ms/step - loss: 7.4838e-04
# Epoch 93/100
# 222/222 - 1s - 6ms/step - loss: 4.6187e-04
# Epoch 94/100
# 222/222 - 3s - 11ms/step - loss: 8.5478e-04
# Epoch 95/100
# 222/222 - 3s - 15ms/step - loss: 7.7629e-04
# Epoch 96/100
# 222/222 - 2s - 8ms/step - loss: 0.0022
# Epoch 97/100
# 222/222 - 1s - 6ms/step - loss: 8.8321e-04
# Epoch 98/100
# 222/222 - 1s - 6ms/step - loss: 7.7789e-04
# Epoch 99/100
# 222/222 - 1s - 6ms/step - loss: 6.3002e-04
# Epoch 100/100
# 222/222 - 1s - 6ms/step - loss: 5.2715e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 348ms/step
# Mean Squared Error (MSE): 193.36272560606568
# Mean Absolute Error (MAE): 2.2738719434078254
# Root Mean Squared Error (RMSE): 13.905492641617041
